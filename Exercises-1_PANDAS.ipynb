# %%
# %matplotlib inline
import pandas as pd

# %%
cast = pd.read_csv('D:/TopMentor_DS_course/File/cast/cast.csv')
cast.head(5)
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
cast['title'].nunique()
# Out:
# 150893

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
k = list(cast[['title','year']].sort_values('year').drop_duplicates().head(2)['title'].unique())
print("the earliest two films are: ", k)
# Out:
# the earliest two films are:  ['Miss Jerry', 'Valsons']

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
# %time
(cast['title']=='Hamlet').sum()
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 113

# %%
# %time
j = cast.set_index('title')     # must faster
len(j.loc['Hamlet'])
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 113

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
(cast['title']=='North by Northwest').sum()
# Out:
# 41

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
cast[cast['title']=='Hamlet'].sort_values(['year'])[['year']].head(1)
# Out:
#         year
# 954648  1911

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
cast[cast['title']=='Treasure Island'].sort_values('year')
# Out:
#                   title  year               name   type  \
# 909157  Treasure Island  1918       Edwin Harley  actor
# 840745  Treasure Island  1918          Joe Grant  actor
# 830114  Treasure Island  1918     Charles Gorman  actor
# 339256  Treasure Island  1918  Francis Carpenter  actor
# 374597  Treasure Island  1920         Lon Chaney  actor
# ...                 ...   ...                ...    ...
# 880460  Treasure Island  1999       Rio Hackford  actor
# 872384  Treasure Island  1999      Paul Gutrecht  actor
# 114904  Treasure Island  1999   Lance (II) Baker  actor
# 934507  Treasure Island  1999          Pat Healy  actor
# 589900  Treasure Island  1999      Jamie Donovan  actor
#
#                       character     n
# 909157          Prologue Player   NaN
# 840745  Undetermined child role   NaN
# 830114          Prologue Player   NaN
# 339256              Jim Hawkins   1.0
# 374597               Blind Pew    5.0
# ...                         ...   ...
# ...

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
cast['year'] = cast['year'].astype('Int64')

# %%
cast[cast['year'] == 1950]['title'].nunique()
# Out:
# 837

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
cast[cast['year'] == 1960]['title'].nunique()
# Out:
# 952

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
cast[(cast['year'] >= 1950) & (cast['year'] <= 1959)]['title'].nunique()
# Out:
# 9160

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
list(cast[cast['title'] == 'Batman']['year'].unique())
# Out:
# [1943, 1989]

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
# # cast.isnull().sum()
# cast['n'].fillna(0,inplace=True)

# %%
cast[cast['title']=='Inception']['character'].nunique()
# Out:
# 23

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
cast[cast['title']=='Inception']['n'].isnull().sum()
# Out:
# 8

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
len(cast[cast['title']=='Inception']['n'])
# Out:
# 27

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
a = cast[cast['title']=='Inception'].sort_values('n')
a[a['n'].notnull()]
# Out:
#             title  year                  name   type              character  \
# 569504  Inception  2010     Leonardo DiCaprio  actor                   Cobb
# 829338  Inception  2010  Joseph Gordon-Levitt  actor                 Arthur
# 907468  Inception  2010             Tom Hardy  actor                  Eames
# 176819  Inception  2010          Tom Berenger  actor               Browning
# 314663  Inception  2010         Michael Caine  actor                  Miles
# 878274  Inception  2010            Lukas Haas  actor                   Nash
# 783405  Inception  2010       Johnathan Geare  actor        James (3 years)
# 321091  Inception  2010          Earl Cameron  actor       Elderly Bald Man
# 932903  Inception  2010          Ryan Hayward  actor                 Lawyer
# 684215  Inception  2010             Russ Fega  actor             Cab Driver
# 417982  Inception  2010         Nicolas Clerc  actor         Bridge Sub Con
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
a = list(cast[cast['title']=='Sleuth'].sort_values('n')['name'].unique())
a
# Out:
# ['Michael Caine', 'Alec Cawthorne', 'Kenneth Branagh', 'Alec (II) Cawthorne']

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
list(cast[(cast['title']=='Sleuth') & (cast['year']==2007)].sort_values('n')['name'].unique())
# Out:
# ['Michael Caine', 'Kenneth Branagh', 'Alec (II) Cawthorne']

# %%
t = cast.set_index(['title','year'])
t.loc['Sleuth'].loc[2007].sort_values('n')
# Out:
#                      name   type          character    n
# year
# 2007        Michael Caine  actor             Andrew  1.0
# 2007      Kenneth Branagh  actor  Other Man on T.V.  NaN
# 2007  Alec (II) Cawthorne  actor  Inspector Doppler  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast[(cast['title']=='Hamlet') & (cast['year']==1921)]['character'].nunique()
# Out:
# 3

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
cast[(cast['title']=='Hamlet') & (cast['year']==1996)]['character'].nunique()
# Out:
# 22

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
cast[(cast['title']=='Hamlet')]['character'].nunique()
# Out:
# 52

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
cast[cast['character']=='Ophelia']['name'].nunique()
# Out:
# 4

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast[cast['character']=='The Dude']['name'].nunique()
# Out:
# 6

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast[cast['character']=='The Stranger']['name'].nunique()
# Out:
# 80

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast[cast['name']=='Sidney Poitier']['character'].nunique()
# Out:
# 0

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast[cast['name']=='Judi Dench']['character'].nunique()
# Out:
# 0

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast.year//10*10
# Out:
# 0          2010
# 1          1980
# 2          2010
# 3          2010
# 4          2010
#            ...
# 1048570    2010
# 1048571    2000
# 1048572    1950
# 1048573    2000
# 1048574    1980
# Name: year, Length: 1048575, dtype: Int64

# %%
cast[(cast['name']=='Cary Grant') & (cast['n']==2) & ((cast['year']// 10*10)==1940)].sort_values('year')
# Out:
#                    title  year        name   type    character    n
# 840371  My Favorite Wife  1940  Cary Grant  actor         Nick  2.0
# 840381    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast[(cast['name']=='Cary Grant') & (cast['n']==1) & ((cast['year']// 10*10)==1940)].sort_values('year')
# Out:
#                                        title  year        name   type  \
# 840397               The Howards of Virginia  1940  Cary Grant  actor
# 840353                       His Girl Friday  1940  Cary Grant  actor
# 840399                The Philadelphia Story  1940  Cary Grant  actor
# 840386                             Suspicion  1941  Cary Grant  actor
# 840401                  The Talk of the Town  1942  Cary Grant  actor
# 840377                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 840344                     Destination Tokyo  1943  Cary Grant  actor
# 840369                             Mr. Lucky  1943  Cary Grant  actor
# 840370                             Mr. Lucky  1943  Cary Grant  actor
# 840378                      Once Upon a Time  1944  Cary Grant  actor
# 840336                  Arsenic and Old Lace  1944  Cary Grant  actor
# 840373             None But the Lonely Heart  1944  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast[(cast['year'] // 10*10)==1950]['character'].nunique()
# Out:
# 43660

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
cast[(cast['type']=='actress') & (cast['year'] // 10*10)==1950]['character'].nunique()
# Out:
# 0

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
cast[(cast['n']==1) & (cast['year']<=1980)].sort_values('year')['character'].nunique()
# Out:
# 16078

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
cast[(cast['n']!=1) & (cast['year']<=1980)].sort_values('year')['character'].nunique()
# Out:
# 197763

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
cast[(cast['n'].isnull()) & (cast['year']<=1980)].sort_values('year')['character'].nunique()
# Out:
# 70064
